# %%
things = ["salmonella", "mozzarella", "cinderella"]

# %%
things[2] = things[2].capitalize()
print(things)
# Out:
# ['salmonella', 'mozzarella', 'Cinderella']

# %%
things[1] = things[1].upper()
print(things)
# Out:
# ['salmonella', 'MOZZARELLA', 'Cinderella']

# %%
things.pop(0)
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella']

# %%
def good():
    return ["Harry", "Ron", "Hermione"]

# %%
def get_odds():
    for num in range(10):
        if num % 2 == 1:
            yield num

count = 0
for value in get_odds():
    count += 1
    if count == 3:
        print(value)
        break
# Out:
# 5
