# %%
class Vehicle:
    def __init__(self, vehicle_type):
        self.vehicle_type = vehicle_type


class Automobile(Vehicle):
    def __init__(self, year, make, model, doors, roof):
        super().__init__("car")   # store "car" in the Vehicle superclass
        self.year = year
        self.make = make
        self.model = model
        self.doors = doors
        self.roof = roof


# --- Main App ---

# Collect user input
year = input("Enter the year of the car: ")
make = input("Enter the make of the car: ")
model = input("Enter the model of the car: ")
doors = input("Enter the number of doors (2 or 4): ")
roof = input("Enter the type of roof (solid or sun roof): ")

# Create an Automobile object
car = Automobile(year, make, model, doors, roof)

# Output the data
print("\nVehicle Information")
print(f"  Vehicle type: {car.vehicle_type}")
print(f"  Year: {car.year}")
print(f"  Make: {car.make}")
print(f"  Model: {car.model}")
print(f"  Number of doors: {car.doors}")
print(f"  Type of roof: {car.roof}")
# Out:
# Enter the year of the car:  2000
# Enter the make of the car:  Ford
# Enter the model of the car:  Taurus
# Enter the number of doors (2 or 4):  4
# Enter the type of roof (solid or sun roof):  Solid
# Vehicle Information
#   Vehicle type: car
#   Year: 2000
#   Make: Ford
#   Model: Taurus
#   Number of doors: 4
#   Type of roof: Solid
